# %%
# Uncomment if needed to install dependencies in requirements.txt
# %pip install -r ../requirements.txt

# %%
import sys
from pathlib import Path
import mne
import numpy as np
mne.set_log_level("ERROR")

# %%
PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.data import get_subject_data
from src.model import csp_lda_classifier
from src.evaluate import evaluate

# %%
# Get all subject folders from Physionet motor movement/imagery dataset
subjects = sorted([child for child in (PROJECT_ROOT/"data"/"files").iterdir() if child.is_dir()])
num_subjects = len(subjects)

accuracies = [] #Stores accuracies for each subject
bci_literate_subjects = [] # Stores subjects with accuracy above 70%

# Get results for every subject in physionet dataset
for subject_id, subject in enumerate(subjects):
    subject_id+=1
    print((f"Processing subject {subject_id}/{num_subjects}"))

    runs = sorted([run for run in subject.glob("*.edf")])
    train_runs = [runs[3], runs[7]]  # Select runs 4, 8 for motor imagery training data
    valid_runs = [runs[11]] # Select run 12 for testing motor imagery model

    # Retrieve EEG data for subject.
    # 0.5 second offset from event onset to account for subject reaction time to event.
    # 3.5 second duration because events are 4 seconds long.
    # T1 and T2 as classes to retrieve data for. T1=left hand. T2=right hand.
    train_data = get_subject_data(train_runs, ("T1","T2"))
    
    clf = csp_lda_classifier() # Create classifier object

    # Evaluate performance
    # Within run classification if only one run in used in data
    # Cross-run classficiation if multiple runs included in data
    mean, scores = evaluate(clf, train_data)

    clf.fit(train_data["x"], train_data["y"]) # Fit classifier with data
 
    valid_data = get_subject_data(valid_runs, ("T1","T2")) # Get validation data

    #Get accuracy of model on validation data
    preds = clf.predict(valid_data["x"])
    corrects = preds == valid_data["y"]
    accuracy = corrects.mean()
    print(f"Validation accuracy: {accuracy:.3f}", end="\n\n")

    # Store accuracy and check if subject is BCI literate
    accuracies.append(accuracy)
    if accuracy >= 0.7:
        bci_literate_subjects.append(subject_id)

print(f"Average accuracy across all subjects: {np.mean(accuracies):.3f}")
print(f"Number of BCI literate subjects: {len(bci_literate_subjects)}/{num_subjects}")
print(f"BCI literate subjects: {bci_literate_subjects}")
# Out:
# Processing subject 1/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.733
#
# Processing subject 2/109
# Evaluation accuracy: 0.933
# Validation accuracy: 0.733
#
# Processing subject 3/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.667
#
# Processing subject 4/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.400
#
# Processing subject 5/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 6/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 7/109
# Evaluation accuracy: 0.800
# Validation accuracy: 1.000
#
# Processing subject 8/109
# Evaluation accuracy: 0.433
# Validation accuracy: 0.400
#
# Processing subject 9/109
# Evaluation accuracy: 0.333
# Validation accuracy: 0.467
#
# Processing subject 10/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.267
#
# Processing subject 11/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.733
#
# Processing subject 12/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.800
#
# Processing subject 13/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.467
#
# Processing subject 14/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.467
#
# Processing subject 15/109
# Evaluation accuracy: 0.600
# Validation accuracy: 0.667
#
# Processing subject 16/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.667
#
# Processing subject 17/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.600
#
# Processing subject 18/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.467
#
# Processing subject 19/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.333
#
# Processing subject 20/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.467
#
# Processing subject 21/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 22/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.600
#
# Processing subject 23/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.667
#
# Processing subject 24/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.733
#
# Processing subject 25/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.800
#
# Processing subject 26/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.800
#
# Processing subject 27/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.600
#
# Processing subject 28/109
# Evaluation accuracy: 0.400
# Validation accuracy: 0.533
#
# Processing subject 29/109
# Evaluation accuracy: 0.933
# Validation accuracy: 1.000
#
# Processing subject 30/109
# Evaluation accuracy: 0.633
# Validation accuracy: 0.600
#
# Processing subject 31/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.733
#
# Processing subject 32/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.867
#
# Processing subject 33/109
# Evaluation accuracy: 0.600
# Validation accuracy: 0.733
#
# Processing subject 34/109
# Evaluation accuracy: 0.733
# Validation accuracy: 1.000
#
# Processing subject 35/109
# Evaluation accuracy: 0.600
# Validation accuracy: 0.533
#
# Processing subject 36/109
# Evaluation accuracy: 0.300
# Validation accuracy: 0.600
#
# Processing subject 37/109
# Evaluation accuracy: 0.586
# Validation accuracy: 0.500
#
# Processing subject 38/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.400
#
# Processing subject 39/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.600
#
# Processing subject 40/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.467
#
# Processing subject 41/109
# Evaluation accuracy: 0.588
# Validation accuracy: 0.533
#
# Processing subject 42/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.933
#
# Processing subject 43/109
# Evaluation accuracy: 0.600
# Validation accuracy: 0.733
#
# Processing subject 44/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.600
#
# Processing subject 45/109
# Evaluation accuracy: 0.767
# Validation accuracy: 0.667
#
# Processing subject 46/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.467
#
# Processing subject 47/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.400
#
# Processing subject 48/109
# Evaluation accuracy: 0.833
# Validation accuracy: 0.733
#
# Processing subject 49/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.667
#
# Processing subject 50/109
# Evaluation accuracy: 0.433
# Validation accuracy: 0.533
#
# Processing subject 51/109
# Evaluation accuracy: 0.633
# Validation accuracy: 0.667
#
# Processing subject 52/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.800
#
# Processing subject 53/109
# Evaluation accuracy: 0.733
# Validation accuracy: 0.933
#
# Processing subject 54/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.867
#
# Processing subject 55/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.667
#
# Processing subject 56/109
# Evaluation accuracy: 0.833
# Validation accuracy: 0.800
#
# Processing subject 57/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 58/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.467
#
# Processing subject 59/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.467
#
# Processing subject 60/109
# Evaluation accuracy: 0.767
# Validation accuracy: 0.800
#
# Processing subject 61/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.667
#
# Processing subject 62/109
# Evaluation accuracy: 0.867
# Validation accuracy: 0.667
#
# Processing subject 63/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.600
#
# Processing subject 64/109
# Evaluation accuracy: 0.633
# Validation accuracy: 0.571
#
# Processing subject 65/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.600
#
# Processing subject 66/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.400
#
# Processing subject 67/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.600
#
# Processing subject 68/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.400
#
# Processing subject 69/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.667
#
# Processing subject 70/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.667
#
# Processing subject 71/109
# Evaluation accuracy: 0.767
# Validation accuracy: 0.667
#
# Processing subject 72/109
# Evaluation accuracy: 0.821
# Validation accuracy: 0.867
#
# Processing subject 73/109
# Evaluation accuracy: 0.464
# Validation accuracy: 0.571
#
# Processing subject 74/109
# Evaluation accuracy: 0.479
# Validation accuracy: 0.286
#
# Processing subject 75/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.667
#
# Processing subject 76/109
# Evaluation accuracy: 0.464
# Validation accuracy: 0.286
#
# Processing subject 77/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.533
#
# Processing subject 78/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.733
#
# Processing subject 79/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.600
#
# Processing subject 80/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.533
#
# Processing subject 81/109
# Evaluation accuracy: 0.667
# Validation accuracy: 0.400
#
# Processing subject 82/109
# Evaluation accuracy: 0.400
# Validation accuracy: 0.600
#
# Processing subject 83/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.533
#
# Processing subject 84/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.533
#
# Processing subject 85/109
# Evaluation accuracy: 0.800
# Validation accuracy: 0.533
#
# Processing subject 86/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.600
#
# Processing subject 87/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 88/109
# Evaluation accuracy: 0.421
# Validation accuracy: 0.526
#
# Processing subject 89/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.533
#
# Processing subject 90/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.600
#
# Processing subject 91/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.600
#
# Processing subject 92/109
# Evaluation accuracy: 0.605
# Validation accuracy: 0.474
#
# Processing subject 93/109
# Evaluation accuracy: 0.733
# Validation accuracy: 0.800
#
# Processing subject 94/109
# Evaluation accuracy: 0.833
# Validation accuracy: 0.467
#
# Processing subject 95/109
# Evaluation accuracy: 0.433
# Validation accuracy: 0.467
#
# Processing subject 96/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.600
#
# Processing subject 97/109
# Evaluation accuracy: 0.433
# Validation accuracy: 0.533
#
# Processing subject 98/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.733
#
# Processing subject 99/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.533
#
# Processing subject 100/109
# Evaluation accuracy: 0.417
# Validation accuracy: 0.500
#
# Processing subject 101/109
# Evaluation accuracy: 0.600
# Validation accuracy: 0.533
#
# Processing subject 102/109
# Evaluation accuracy: 0.500
# Validation accuracy: 0.786
#
# Processing subject 103/109
# Evaluation accuracy: 0.533
# Validation accuracy: 0.533
#
# Processing subject 104/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.800
#
# Processing subject 105/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.333
#
# Processing subject 106/109
# Evaluation accuracy: 0.467
# Validation accuracy: 0.600
#
# Processing subject 107/109
# Evaluation accuracy: 0.567
# Validation accuracy: 0.600
#
# Processing subject 108/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.600
#
# Processing subject 109/109
# Evaluation accuracy: 0.700
# Validation accuracy: 0.333
#
# Average accuracy across all subjects: 0.603
# Number of BCI literate subjects: 27/109
# BCI literate subjects: [1, 2, 7, 11, 12, 24, 25, 26, 29, 31, 32, 33, 34, 42, 43, 48, 52, 53, 54, 56, 60, 72, 78, 93, 98, 102, 104]
